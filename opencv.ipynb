# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseLuisBarba/deepLearning/blob/main/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Basic Operations**
#
# > Basic Operations with OpenCV:
#
# - Importing OpenCV
# - Loading an image
# - Image Shape/ Resolution
# - Displaying the image
# - Resizing the image
# - Converting to Grayscale

# %% [markdown]
# El procesamiento de imágenes digitales es el uso de algoritmos informáticos para realizar el procesamiento de imágenes en imágenes digitales. Permite aplicar una gama mucho más amplia de algoritmos a los datos de entrada - el objetivo del procesamiento de imágenes digitales es mejorar los datos de la imagen (características) mediante la supresión de distorsiones no deseadas y/o la mejora de algunas características importantes de la imagen para que nuestros modelos de IA puedan beneficiarse de estos datos mejorados para trabajar.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/DeepLearning/OpenCV/penguin.png'

# %%
import cv2

# %% [markdown]
# #**Loading an image using OpenCV**
#
# > We can read the image using imread module.
#
# > It takes 2 arguments:
# - path: A string representing the path of the image to be read.
# - flag: It specifies the way in which image should be read. It’s default value is cv2.IMREAD_COLOR
#
# > Describing the 3 possible values of flag below:
#
# - cv2.IMREAD_COLOR: It specifies to load a color image. Any transparency of image will be neglected. It is the default flag. Alternatively, we can pass integer value 1 for this flag.
# - cv2.IMREAD_GRAYSCALE: It specifies to load an image in grayscale mode. Alternatively, we can pass integer value 0 for this flag.
# - cv2.IMREAD_UNCHANGED: It specifies to load an image as such including alpha channel. Alternatively, we can pass integer value -1 for this flag.
#
# > In short:
#
# The 1 in the flag parameter denotes that it is a color image.
# If the parameter is 0, it would mean that the image being imported is a grayscale image.

# %%
img = cv2.imread(path,cv2.IMREAD_COLOR)
print(img)
# Out:
# [[[194 169 136]
#   [194 169 136]
#   [194 169 136]
#   ...
#   [170 137  87]
#   [170 137  87]
#   [170 137  87]]
#
#  [[194 169 136]
#   [194 169 136]
#   [194 169 136]
#   ...
#   [170 137  87]
#   [170 137  87]
#   [170 137  87]]
#
#  [[193 169 139]
#   [193 169 139]
#   [193 169 139]
#   ...
#   [170 137  87]
#   [170 137  87]
#   [170 137  87]]
#
#  ...
#
#  [[187 176 168]
#   [188 177 169]
#   [190 179 172]
#   ...
#   [128 112  98]
#   [128 112  98]
#   [128 112  98]]
#
#  [[185 176 168]
#   [186 177 169]
#   [188 179 172]
#   ...
#   [129 114  98]
#   [129 114  98]
#   [129 114  98]]
#
#  [[185 176 168]
#   [186 177 169]
#   [188 179 172]
#   ...
#   [129 114  98]
#   [129 114  98]
#   [129 114  98]]]

# %% [markdown]
# #**Image Shape and resolution**
#
# > By shape of the image, we mean the shape of the NumPy array. As you see from executing the code, the matrix consists of 530 rows and 1136 columns.
#
# The last value 3 indicates the no. of channels.
#
# - 3 = coloured image
# - 1 = black and white/grayscale image

# %%
img.shape
# Out:
# (530, 1136, 3)

# %%
from google.colab.patches import cv2_imshow
#Here, "Penguin" is the name that'll be given to the window
cv2_imshow(img)
cv2.waitKey(0)
# destroying all windows
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1136x530 at 0x7F979769F160>

# %% [markdown]
# As you can see, we first import the image using imread. We require a window output to display the images, right?
#
# We use the imshow function to display the image by opening a window.
#
# Later, we wait for a user event. waitKey makes the window static until the user presses a key. The parameter passed to it is the time in milliseconds.
#
# And lastly, we use destroyAllWindows to close the window based on the waitForKey parameter.

# %% [markdown]
# #**Resizing the image**

# %%
resizedImg =  cv2.resize(img,(int(0.5*img.shape[1]),int(0.5*img.shape[0])))

# %%
cv2_imshow(resizedImg)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=568x265 at 0x7F97805E1C40>

# %%
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1136x530 at 0x7F97976A3E20>

# %% [markdown]
# #**Converting to Grayscale**
# > cvtColor() function in OpenCV is very helpful in converting color channels from one to another such as BRG to HSV or BRG to RGB. The same method can be used to convert BRG to GRAY by using the cv2.cvtColor(img,cv2.BGR2GRAY)
#
# Another method is to specify 0 instead of 1 as the flag parameter in imread(). That way, your image will be read as a grayscale image.

# %%
grayImg = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(grayImg)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=1136x530 at 0x7F97805F7700>

# %%
grayImg.shape
# Out:
# (530, 1136)
